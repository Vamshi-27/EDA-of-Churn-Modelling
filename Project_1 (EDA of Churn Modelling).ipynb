# %% [markdown]
# ## **EDA of Churn Modelling Dataset**

# %% [markdown]
# ## **Problem Statement**
# Customer churn is a critical issue for banks as it directly impacts profitability and long-term growth. This dataset contains customer demographic details, financial information, and account activity data, along with a target variable indicating whether a customer has exited the bank.
#
# The main objectives of this analysis are:
#
# - To understand the overall structure and quality of the dataset.
#
# - To identify patterns and trends related to customer churn.
#
# - To analyze the relationship between customer attributes (age, gender, geography, balance, etc.) and churn behavior.
#
# - To determine the key factors that contribute most to customer exit.
#
# - To generate insights that can help improve customer retention strategies.
#
# Exploratory Data Analysis (EDA) will help uncover meaningful insights and prepare the dataset for further predictive modeling.

# %% [markdown]
# # **Project Objectives**
# The objectives of this project are to:
# - Understand the dataset structure and variables
# - Perform data wrangling and data cleaning
# - Conduct univariate, bivariate, and multivariate analysis
# - Identify patterns, trends, and anomalies
#
# - Summarize insights for decision-making
# - Provide conclusions and actionable recommendations

# %% [markdown]
# # **Tools and Libraries**
# - Numpy
# - Pandas
# - Matplotlib
# - Seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Dataset Loading**

# %% [markdown]
# **Loading**

# %%
data = pd.read_csv('/content/Churn_Modelling.csv')

# %% [markdown]
# **Display sample records**

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
#  **Dataset Source:**
# - Kaggle – Bank Customer Churn / Churn Modelling Dataset

# %% [markdown]
# **Size**

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## **Understanding Variables**

# %% [markdown]
# **Column Names**

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# **Data Type**

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# **Data Dictionary**
# | Column Name     | Description                                                            | Data Type   |
# | --------------- | ---------------------------------------------------------------------- | ----------- |
# | RowNumber       | Unique row identifier for each record                                  | Numerical   |
# | CustomerId      | Unique customer identification number                                  | Numerical   |
# | Surname         | Customer’s last name                                                   | Text        |
# | CreditScore     | Customer’s credit score                                                | Numerical   |
# | Geography       | Country where the customer resides (e.g., France, Germany, Spain)      | Categorical |
# | Gender          | Customer’s gender                                                      | Categorical |
# | Age             | Customer’s age                                                         | Numerical   |
# | Tenure          | Number of years the customer has been with the bank                    | Numerical   |
# | Balance         | Customer’s account balance                                             | Numerical   |
# | NumOfProducts   | Number of bank products the customer is using                          | Numerical   |
# | HasCrCard       | Whether the customer has a credit card (1 = Yes, 0 = No)               | Categorical |
# | IsActiveMember  | Whether the customer is an active member (1 = Yes, 0 = No)             | Categorical |
# | EstimatedSalary | Estimated annual salary of the customer                                | Numerical   |
# | Exited          | Whether the customer left the bank (1 = Yes, 0 = No) — Target Variable | Categorical |

# %% [markdown]
# ## **Preliminary Data Exploration**

# %% [markdown]
# **Dataset shape**

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# **Head and Tail**

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# **Dataset information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **Data types**

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# **Statistical Summary for Numerical values**

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# **Statistical summary for Objects**

# %%
data.describe(include='object')
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# **Unique values**

# %%
df = data[['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
       'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited']]
for x in df:
  print(f"{x}--->{df[x].unique()}")
  print()
# Out:
# RowNumber--->[    1     2     3 ...  9998  9999 10000]
#
# CustomerId--->[15634602 15647311 15619304 ... 15584532 15682355 15628319]
#
# Surname--->['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
#
# CreditScore--->[619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
# ...

# %% [markdown]
# **Value counts**

# %%
for x in df:
  print(df[x].value_counts())
  print()
# Out:
# RowNumber
# 9984    1
# 9983    1
# 9982    1
# 9981    1
# 9980    1
#        ..
# 5       1
# 4       1
# 3       1
# 2       1
# 1       1
# Name: count, Length: 10000, dtype: int64
#
# CustomerId
# 15656710    1
# 15768163    1
# 15672754    1
# 15719276    1
# 15692664    1
#            ..
# 15737888    1
# 15701354    1
# 15619304    1
# 15647311    1
# 15634602    1
# Name: count, Length: 10000, dtype: int64
#
# Surname
# Smith        32
# Scott        29
# Martin       29
# Walker       28
# Brown        26
#              ..
# Hull          1
# Sturdee       1
# Flannagan     1
# Dwyer         1
# Corby         1
# Name: count, Length: 2932, dtype: int64
#
# CreditScore
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 358      1
# 412      1
# 382      1
# 373      1
# 419      1
# Name: count, Length: 460, dtype: int64
#
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
#
# Gender
# Male      5457
# ...

# %% [markdown]
# ## **Data Wrangling**

# %% [markdown]
# **Column Handling**

# %% [markdown]
# Drop Irrelevant or Redundant columns

# %%
data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1,inplace=True)

# %% [markdown]
# Rename columns

# %%
data.rename(columns={
    "CreditScore": "credit_score",
    "Geography": "geography",
    "Gender": "gender",
    "Age": "age",
    "Tenure": "tenure",
    "Balance": "balance",
    "NumOfProducts": "num_of_products",
    "HasCrCard": "has_credit_card",
    "IsActiveMember": "is_active_member",
    "EstimatedSalary": "estimated_salary",
    "Exited": "churn"
}, inplace=True)

# %% [markdown]
# **Feature Creation**

# %% [markdown]
# **1. Age Group Segmentation**
#
#    * Create categorical age groups:
#
#       18–30 -> Young
#
#       31–45 -> Middle Age
#
#       46–60 -> Senior
#
#       60+ -> Elder
#   -  Age as a number is less interpretable
#
#   - Age segments help identify churn-prone age categories
#
# **2. Tenure Group**
#
#    * Segment tenure into:
#
#       0–3 years -> New Customer
#
#       4–7 years -> Mid-term
#
#       8–10 years -> Long-term
#
#    * Helps analyze loyalty vs churn
#
#    * Detects whether new or old customers churn more

# %%
# Create Age Groups
data["age_group"] = pd.cut(data["age"],
                         bins=[18, 30, 45, 60, 100],
                         labels=["Young", "Middle_Age", "Senior", "Elder"],
                         include_lowest=True)

# Create Tenure Groups
data["tenure_group"] = pd.cut(data["tenure"],
                            bins=[-1, 3, 7, 10],
                            labels=["New_Customer", "Mid_Term", "Long_Term"])

# %% [markdown]
# ## **Data Cleaning and Preparation**

# %% [markdown]
# **Duplicate Handling**

# %% [markdown]
# Identify duplicate rows - no values are duplicated

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Missing Value Treatment**

# %%
data.isnull().sum()
# Out:
# credit_score        0
# geography           0
# gender              0
# age                 0
# tenure              0
# balance             0
# num_of_products     0
# has_credit_card     0
# is_active_member    0
# estimated_salary    0
# churn               0
# age_group           0
# tenure_group        0
# dtype: int64

# %% [markdown]
# ## **Data Visualization and Analysis**

# %% [markdown]
# **Univariate Analysis**

# %%
plt.hist(data['age'], bins=20)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# **Insights:**
#
# - Most customers are between 30–45 years.
#
# - Distribution is slightly right-skewed.
#
# - Very few customers above 70 (possible outliers).

# %%
plt.hist(data['credit_score'], bins=20)
plt.show()

# %% [markdown]
# **Insights:**
#
# - Majority scores lie between 600–750.
#
# - Distribution is approximately normal.
#
# - Very low scores are rare.

# %%
sns.boxplot(y=data['balance'])
plt.show()

# %% [markdown]
# **Insights:**
#
# - Many customers have zero balance.
#
# - Several extreme high-value outliers exist.
#
# - Balance distribution is highly skewed.

# %%
sns.violinplot(y=data['estimated_salary'])
plt.show()

# %% [markdown]
# **Insights:**
# - Salary is evenly spread across ranges.
#
# - No strong skewness observed.
#
# - Wide variation in salary values.

# %%
sns.countplot(x='geography', data=data)
plt.show()

# %% [markdown]
# **Insights:**
#
# - France has the highest number of customers.
#
# - Germany and Spain have fewer customers.
#
# - Customer distribution is uneven across countries.

# %%
sns.countplot(x='gender', data=data)
plt.show()

# %% [markdown]
# **Insights:**
# - France has the highest number of customers.
#
# - Germany and Spain have fewer customers.
#
# - Customer distribution is uneven across countries.

# %%
data['churn'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel("")
plt.show()

# %% [markdown]
# **Insights:**
# - Around 80% customers did not churn.
#
# - About 20% customers exited.
#
# - Dataset is imbalanced.

# %%
data['tenure'].value_counts().sort_index().plot(kind='bar')
plt.show()

# %% [markdown]
# **Insights:**
# - Customers are distributed across all tenure years.
#
# - Mid-term tenure customers are slightly higher.
#
# - No extreme concentration at one tenure level.

# %%
data['age'].plot(kind='density')
plt.show()

# %% [markdown]
# **Insights**
# - Highest density around 35–40 years.
#
# - Smooth peak in middle age group.
#
# - Density decreases at higher ages.

# %% [markdown]
# **Bivariate Analysis**

# %%
sns.boxplot(x='churn', y='age', data=data)
plt.show()

# %% [markdown]
# **Age vs Churn**
#
# - Churned customers are generally older.
#
# - Median age is higher for churn group.
#
# - Younger customers churn less.

# %%
sns.boxplot(x='churn', y='balance', data=data)
plt.show()

# %% [markdown]
# **Balance vs Churn**
#
# - Churned customers tend to have higher balances.
#
# - High balance outliers exist in churn group.
#
# - Low balance customers mostly stay.

# %%
pd.crosstab(data['gender'], data['churn']).plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# **Gender vs Churn**
#
# - Females churn slightly more than males.
#
# - Both genders mostly stay with the bank.
#
# - Gender impact is moderate.

# %%
sns.countplot(x='geography', hue='churn', data=data)
plt.show()

# %% [markdown]
# **Geography vs Churn**
#
# - Germany has the highest churn rate.
#
# - France has the lowest churn rate.
#
# - Geography influences churn behavior.

# %%
plt.scatter(data['age'], data['balance'])
plt.show()

# %% [markdown]
# **Age vs Balance**
#
# - No strong linear relationship observed.
#
# - Older customers show higher balance variation.
#
# - Data points are widely scattered.

# %%
sns.barplot(x='is_active_member', y='churn', data=data)
plt.show()

# %% [markdown]
# **Active Member vs Churn**
#
# - Inactive members churn more.
#
# - Active members mostly remain.
#
# - Strong relationship between activity and churn.

# %%
data.groupby('tenure')['balance'].mean().plot()
plt.show()

# %% [markdown]
# **Tenure vs Average Balance**
#
# - Balance fluctuates across tenure years.
#
# - No steady increasing trend.
#
# - Mid-tenure customers show moderate balance.

# %%
sns.violinplot(x='churn', y='credit_score', data=data)
plt.show()

# %% [markdown]
# **Credit Score vs Churn**
#
# - Lower credit score customers churn more.
#
# - Distribution overlaps between groups.
#
# - Credit score impact is moderate.

# %% [markdown]
# **Multivariate Analysis**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.select_dtypes(include=['int64','float64']).corr(), annot=True)
plt.show()

# %% [markdown]
# **Correlation Heatmap**
# - Age is slightly related to churn (older customers leave more).
#
# - Active members are less likely to churn.
#
# - Most variables do not have strong relationships with each other.

# %%
sns.pairplot(data[['age','balance','credit_score','churn']], hue='churn')
plt.show()

# %% [markdown]
# **Pair Plot**
#
# - Age shows visible separation between churn groups.
#
# - Balance and credit score overlap heavily.
#
# - No clear clustering pattern overall.

# %%
sns.scatterplot(x='age', y='balance', hue='churn', data=data)
plt.show()

# %% [markdown]
# **Scatter Plot**
#
# - Older high-balance customers churn more.
#
# - Younger customers mostly remain.
#
# - No strong linear pattern exists.

# %% [markdown]
# ## **Key Insights Summary**
#
# * Older customers are more likely to churn than younger customers.
#
# * Inactive members show significantly higher churn rates compared to active members.
#
# - Customers from Germany have a higher churn rate than other regions.
#
# - Customers with higher account balances tend to churn more frequently.
#
# - Credit score has a moderate influence on churn behavior.
#
# - The dataset shows class imbalance, as most customers did not churn.

# %% [markdown]
# ## **Conclusion**
#
# - Age, activity status, geography, and balance are the key factors influencing churn.
#
# - Customer engagement plays a crucial role in retention.
#
# - Older and inactive customers form the high-risk churn segment.
#
# - There is no strong multicollinearity among variables.
#
# - The dataset is suitable for building a churn prediction model.

# %% [markdown]
# ## **Recommendations**
#
# - Strengthen engagement strategies to reduce churn among inactive customers.
#
# - Provide targeted offers and loyalty programs for older customers.
#
# - Implement region-specific retention strategies in high-churn areas like Germany.
#
# - Offer personalized services to high-balance customers to improve retention.
#
# - Develop a predictive churn model to identify and retain at-risk customers early.
